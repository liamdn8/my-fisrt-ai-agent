# %% [markdown]
# Import python lib

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv()
OPEN_AI_URL = os.getenv("OPEN_AI_URL")
OPEN_AI_API_KEY = os.getenv("OPEN_API_KEY")

print("Open AI URL: ", OPEN_AI_URL)
print("Open AI KEY: ", OPEN_AI_API_KEY)
# Out:
# Open AI URL:  None
# Open AI KEY:  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
